# %% [markdown]
# ### ShapeNetRendering

# %% [markdown]
# ##### Download

# %%
# !wget -P /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets http://cvgl.stanford.edu/data2/ShapeNetRendering.tgz
# Out:
# --2022-10-06 10:34:19--  http://cvgl.stanford.edu/data2/ShapeNetRendering.tgz
# Resolving cvgl.stanford.edu (cvgl.stanford.edu)... 171.64.64.64
# Connecting to cvgl.stanford.edu (cvgl.stanford.edu)|171.64.64.64|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cvgl.stanford.edu/data2/ShapeNetRendering.tgz [following]
# --2022-10-06 10:34:19--  https://cvgl.stanford.edu/data2/ShapeNetRendering.tgz
# Connecting to cvgl.stanford.edu (cvgl.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12318245442 (11G) [application/x-gzip]
# Saving to: ‘/content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/ShapeNetRendering.tgz’
#
# ShapeNetRendering.t 100%[===================>]  11.47G  13.9MB/s    in 13m 57s
#
# 2022-10-06 10:48:16 (14.0 MB/s) - ‘/content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/ShapeNetRendering.tgz’ saved [12318245442/12318245442]

# %% [markdown]
# ##### Unzip

# %%
# !tar -xvf /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/ShapeNetRendering.tgz -C /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets
# Out:
# Streaming output truncated to the last 5000 lines.
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/07.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/13.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/02.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/12.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/16.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/05.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/23.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/06.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/10.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/17.png
# ShapeNetRendering/02828884/a77b423dbe9f9a34beedb4c8fd29e2d1/rendering/15.png
# ...

# %% [markdown]
# ### ShapeNetVox32

# %%
# !wget -P /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets http://cvgl.stanford.edu/data2/ShapeNetVox32.tgz
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2022-10-05 12:08:52--  https://cvgl.stanford.edu/data2/ShapeNetVox32.tgz
# Resolving cvgl.stanford.edu (cvgl.stanford.edu)... 171.64.64.64
# Connecting to cvgl.stanford.edu (cvgl.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22218020 (21M) [application/x-gzip]
# Saving to: ‘/content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/ShapeNetVox32.tgz’
#
# ShapeNetVox32.tgz   100%[===================>]  21.19M  14.2MB/s    in 1.5s
#
# 2022-10-05 12:08:54 (14.2 MB/s) - ‘/content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/ShapeNetVox32.tgz’ saved [22218020/22218020]

# %%
# !tar -xvf /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/ShapeNetVox32.tgz -C /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets

# %% [markdown]
# ### Pix3D

# %%
# !wget -P /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets http://pix3d.csail.mit.edu/data/pix3d.zip
# Out:
# --2022-10-05 11:53:31--  http://pix3d.csail.mit.edu/data/pix3d.zip
# Resolving pix3d.csail.mit.edu (pix3d.csail.mit.edu)... 128.52.131.62
# Connecting to pix3d.csail.mit.edu (pix3d.csail.mit.edu)|128.52.131.62|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3783261880 (3.5G) [application/zip]
# Saving to: ‘/content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/pix3d.zip’
#
# pix3d.zip           100%[===================>]   3.52G  42.1MB/s    in 85s
#
# 2022-10-05 11:54:57 (42.3 MB/s) - ‘/content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/pix3d.zip’ saved [3783261880/3783261880]

# %%
# !unzip /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/pix3d.zip -d /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/Pix3D

# %% [markdown]
# ### Pascal3D

# %%
# !wget -P /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets ftp://cs.stanford.edu/cs/cvgl/PASCAL3D+_release1.0.zip
# Out:
# --2022-10-05 11:54:58--  ftp://cs.stanford.edu/cs/cvgl/PASCAL3D+_release1.0.zip
#            => ‘/content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/PASCAL3D+_release1.0.zip’
# Resolving cs.stanford.edu (cs.stanford.edu)... 171.64.64.64
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /cs/cvgl ... done.
# ==> SIZE PASCAL3D+_release1.0.zip ... 1028017875
# ==> PASV ... done.    ==> RETR PASCAL3D+_release1.0.zip ... done.
# Length: 1028017875 (980M) (unauthoritative)
#
# PASCAL3D+_release1. 100%[===================>] 980.39M  46.9MB/s    in 19s
#
# 2022-10-05 11:55:17 (52.2 MB/s) - ‘/content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/PASCAL3D+_release1.0.zip’ saved [1028017875]

# %%
# !unzip /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/PASCAL3D+_release1.0.zip -d /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/PASCAL3D+_release1.0/Annotations/chair_pascal/2009_001621.mat
#  extracting: /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/PASCAL3D+_release1.0/Annotations/chair_pascal/2009_001611.mat
#   inflating: /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/PASCAL3D+_release1.0/Annotations/chair_pascal/2009_001608.mat
#  extracting: /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/PASCAL3D+_release1.0/Annotations/chair_pascal/2009_001598.mat
#  extracting: /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/PASCAL3D+_release1.0/Annotations/chair_pascal/2009_001575.mat
#  extracting: /content/drive/MyDrive/Colab_Notebooks/L4_Project/Datasets/PASCAL3D+_release1.0/Annotations/chair_pascal/2009_001507.mat
# ...
